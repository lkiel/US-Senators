# %% [markdown]
# # Data Acquisition Notebook
#
# ## Students
#
# * Team: `18`
# * Students: `Quentin Bacuet, Ali Alami-Idrissi, Keshav Singh, Leandro Kieliger`
# * Dataset: `US-Senators`
#
# ## Description
#
# This notebook contains the code necessary to collect data from the ProPublica Congress API. In addition, data undergoes some basic processing steps before being stored in .pickle format.

# %% [markdown]
# ## Required librairies

# %%
import pandas as pd
import numpy as np
import requests
import json
import os
import re

data_folder = 'data/'

# %% [markdown]
# ## Loading the API key
#
# The API key should be stored in a text file alongside the project. To obtain the API key, visit https://projects.propublica.org/api-docs/congress-api/

# %%
API_KEY = ""

with open('api_key.txt') as f:
    API_KEY = f.read()

HEADERS = {"X-Api-Key": API_KEY}

# %% [markdown]
# ## Creating required folders

# %%
def create_folder(path):
    if not os.path.exists(path):
        os.makedirs(path)

create_folder(data_folder)
create_folder(data_folder + 'committees')
create_folder(data_folder + 'senate_members')
create_folder(data_folder + 'votes')
create_folder(data_folder + 'lobby')
create_folder(data_folder + 'bills')

# %% [markdown]
# ## Fetching bills
#
# Bills can be fetched by querying the following url:
# https://api.propublica.org/congress/v1/{congress}/senate/bills/introduced.json?offset={offset}
#
# * The `congress` parameter is used to specify the congress for which we want to query bills. A congress is a meeting of the American legislative branch which lasts two years. It is composed of two chambers, the senate and the house of representatives. Senators are elected for a period of 6 years.
#
# * The `offset` parameter is used to navigate through the results since only 20 results are returned per request.

# %%
bill_str = "https://api.propublica.org/congress/v1/{congress}/senate/bills/introduced.json?offset={offset}"

bill_list = []
more_data_available = True
request_offset = 0

while more_data_available :
    res = requests.get(url = bill_str.format(congress=115, offset = request_offset), headers = HEADERS)
    if('results' in res.json()):
        
        # Print progress status
        print(request_offset, end='\r')
        
        # Verify whether there might be additional result to query
        more_data_available = int(res.json()['results'][0]['num_results']) > 0

        if more_data_available:
            # Extract results from JSON response
            bills = res.json()['results'][0]['bills']
            bill_list.append(pd.io.json.json_normalize(bills, record_prefix=True))
    else:
        print(str(request_offset) + ' - Error: ' + res.json()['error'])
    request_offset += 20

# %%
# Save all bills
df = pd.concat(bill_list,sort=True)
df.to_csv(data_folder + "bills/bills.csv")
df.to_pickle(data_folder + "bills/bills.pickle")

# Save only bills that are considered active. That is, bills that are being considered by at least one committee
active_bills = df[(df['active']==1)]
active_bills.to_csv(data_folder + "bills/active_bills.csv")
active_bills.to_pickle(data_folder + "bills/active_bills.pickle")

# %% [markdown]
# ## Fetching co-sponsors for each bill
#
# Each bill has a sponsor ID, this is the ID of the senator that initially pushes the bill for consideration. However, a bill can be co-sponsored by multiple senators. To find those co-sponsors we need ot perform additional requests.

# %%
def extract_cosponsors(cosponsor_list):
    """
    Extract the cosponsor IDs from a list of JSONs
    """
    
    return [x['cosponsor_id'] for x in cosponsor_list]

def cosponsors_for_bill(bill_id, congress=115):
    """
    Get the cosposor data in JSON from a bill ID
    """
    
    req_url = "https://api.propublica.org/congress/v1/{congress}/bills/{bill_id}/cosponsors.json"
    res = requests.get(req_url.format(bill_id=bill_id, congress=congress), headers = HEADERS)
    
    # Extract results from JSON response
    co_sponsors = res.json()['results'][0]['cosponsors']
    
    # Print progress status
    print("Getting cosponsors for bill " + str(bill_id), end="\r")
    
    return co_sponsors

sponsored_bills = active_bills.copy()

# For each bill (row) in the dataframe, return a list of all the cosponsors for that particular bill
# Those results are stored as a new column in the dataframe
sponsored_bills['cosponsors_id'] = sponsored_bills.apply( 
    lambda row: extract_cosponsors(cosponsors_for_bill(row['bill_slug'])) 
    , axis=1
)

# Save the results
sponsored_bills.to_pickle(data_folder + "/bills/bills_and_sponsors.pickle")

# %% [markdown]
# ### Processing the sponsoring data
#
# This section processes the bill with cosponsors dataframe to store them in a convenient way. The sponsor and cosponsors are merged in a common list and the dataframe is reorganized in a way that each bill is represented by a row and each senator as a column. There is then a one in a particular cell if the corresponding senator sponsored the corresponding bill.

# %%
# Extract and merge sponsors for each bill
bs = pd.read_pickle(data_folder + "bills/bills_and_sponsors.pickle")
bs = bs.apply(lambda row: pd.Series([row['bill_id'], row['cosponsors_id'] + [row['sponsor_id']]], index=['bills','sponsors']), axis=1)
bs = bs.set_index('bills')
bs.head(3)

# %%
# Prepare the one-hot encoding for sponsoring information
df = bs['sponsors'].str.join('|').str.get_dummies()
df = df.transpose()

# Save the results
df.to_pickle(data_folder + "member_matrices/member_to_bill_sponsoring.pickle")

df.head(3)

# %% [markdown]
# ## Fetching senate members (congress 80 to 115)
#
# Retrieve senate members for each congress and save as a separate file.

# %%
u = "https://api.propublica.org/congress/v1/{congress}/senate/members.json"

for i in range(80, 115 + 1):
    results = requests.get(url = u.format(congress=i), headers=HEADERS)
    df = pd.io.json.json_normalize(results.json()['results'][0]['members'])
    df.to_csv(data_folder + "senate_members/senate_members_{congress}.csv".format(congress=i))
    df.to_pickle(data_folder + "senate_members/senate_members_{congress}.pickle".format(congress=i))

# %% [markdown]
# ## Fetching Committees from senate
#
# Retrieve all the committees of the senate for congresses 114 and 115

# %%
# Request config
u = "https://api.propublica.org/congress/v1/{congress}/senate/committees.json"

for i in range(114, 115 + 1):
    results_committee = requests.get(url = u.format(congress=i), headers=HEADERS)
    df = pd.io.json.json_normalize(results_committee.json()['results'][0]['committees'])
    df_list = []
    
    # Extract committee information
    for committee_id in df['id']:
        subcommittee_id = df[df['id'] == committee_id]['subcommittees']

        # Fetch data regarding each subcommittee
        for subcommittee in subcommittee_id.values[0]:
            results_sub = requests.get(url = subcommittee['api_uri'], headers=HEADERS)
            if 'results' in results_sub.json():
                df_sub = pd.io.json.json_normalize(results_sub.json()['results'][0]['current_members'])
                df_sub['subcomittee'] = subcommittee['id']
                df_sub['comittee'] = committee_id
                df_list.append(df_sub)

    if len(df_list) > 0:
        df_merged = pd.concat(df_list)
        df_merged.to_csv(data_folder + 'committees/committees_members_{congress}.csv'.format(congress = i))
        df_merged.to_pickle(data_folder + 'committees/committees_members_{congress}.pickle'.format(congress = i))

# %% [markdown]
# # Getting voting position by member
#
# Retrieve all the votes casted by each senator. For our project we use votes casted by senators of the 115th congress.

# %%
raw_senators = pd.DataFrame()

for i in range (115,116):
    df = pd.read_pickle("data/senate_members/senate_members_{congress}.pickle".format(congress = i))
    df['congress'] = i
    raw_senators = pd.concat([raw_senators, df], sort=False)
    
senators_id = raw_senators['id'].unique()

# %%
u = "https://api.propublica.org/congress/v1/members/{member_id}/votes.json?offset={offset}"

import os
import json
import ast

completed_ids = os.listdir("data/votes")

for senator_id in senators_id:

    if "votes_{id}.csv".format(id=senator_id) in completed_ids:
        continue
        
    error_raised = False
    votes_list = []
    data_available = True
    request_offset = 0

    while data_available :
        res = requests.get(url = u.format(member_id = senator_id, offset = request_offset), headers = HEADERS)
        s = re.sub(r'(\s{2,}|\n)', ' ', res.text)

        jObj = json.loads(s)
        
        print(json.dumps(jObj, indent=4))
                
        if(res.status_code == 200):
            data_available = int(jObj['results'][0]['num_results']) > 0

            if data_available:
                # Print progress status
                print(str(senator_id) + " offset: " + str(request_offset), end='\r')
                
                # Extract data from JSON
                votes = jObj['results'][0]['votes']
                votes_list.append(pd.io.json.json_normalize(votes, record_prefix=True))
                
        else:
            print(str(res.status_code))
            error_raised = True
            break
        
        request_offset += 20
        
    if not error_raised and len(votes_list) > 0:
        df = pd.concat(votes_list,sort=False)
        df.to_csv(data_folder + "votes/votes_{id}.csv".format(id=senator_id), index=False)
# Out:
# {
#     "status": "OK",
#     "copyright": "Copyright (c) 2018 Pro Publica Inc. All Rights Reserved.",
#     "results": [
#         {
#             "member_id": "A000360",
#             "num_results": "20",
#             "offset": "0",
#             "votes": [
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "274",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/274.json",
#                     "bill": {
#                         "bill_id": "hr695-115",
#                         "number": "H.R.695",
#                         "sponsor_id": "S001150",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/hr695.json",
#                         "title": "To amend the National Child Protection Act of 1993 to establish a national criminal history background check system and criminal history review program for certain individuals who, related to their employment, have access to children, the elderly, or individuals with disabilities, and for other purposes.",
#                         "latest_action": "Considered by Senate."
#                     },
#                     "amendment": {},
#                     "description": "To amend the National Child Protection Act of 1993 to establish a voluntary national criminal history background check system and criminal history review program for certain individuals who, related to ...",
#                     "question": "On the Motion to Proceed",
#                     "result": "Motion to Proceed Agreed to",
#                     "date": "2018-12-21",
#                     "time": "12:31:00",
#                     "total": {
#                         "yes": 47,
#                         "no": 47,
#                         "present": 0,
#                         "not_voting": 6
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "273",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/273.json",
#                     "bill": {
#                         "bill_id": "hr695-115",
#                         "number": "H.R.695",
#                         "sponsor_id": "S001150",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/hr695.json",
#                         "title": "To amend the National Child Protection Act of 1993 to establish a national criminal history background check system and criminal history review program for certain individuals who, related to their employment, have access to children, the elderly, or individuals with disabilities, and for other purposes.",
#                         "latest_action": "Considered by Senate."
#                     },
#                     "amendment": {},
#                     "description": "To amend the National Child Protection Act of 1993 to establish a voluntary national criminal history background check system and criminal history review program for certain individuals who, related to ...",
#                     "question": "On the Motion",
#                     "result": "Motion Agreed to",
#                     "date": "2018-12-19",
#                     "time": "21:30:00",
#                     "total": {
#                         "yes": 71,
#                         "no": 21,
#                         "present": 0,
#                         "not_voting": 8
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "272",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/272.json",
#                     "bill": {
#                         "bill_id": "pn2209-115",
#                         "number": "PN2209",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2209-115",
#                         "number": "PN2209",
#                         "name": "Joseph Maguire",
#                         "agency": "Office of the Director of National Intelligence"
#                     },
#                     "description": "Joseph Maguire, of Florida, to be Director of the National Counterterrorism Center, Office of the Director of National Intelligence",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-12-19",
#                     "time": "11:22:00",
#                     "total": {
#                         "yes": 95,
#                         "no": 1,
#                         "present": 0,
#                         "not_voting": 4
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "271",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/271.json",
#                     "bill": {
#                         "bill_id": "s756-115",
#                         "number": "S.756",
#                         "sponsor_id": "S001198",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/s756.json",
#                         "title": "A bill to reauthorize and amend the Marine Debris Act to promote international action to reduce marine debris, and for other purposes.",
#                         "latest_action": "Signed by President."
#                     },
#                     "amendment": {},
#                     "description": "A bill to reauthorize and amend the Marine Debris Act to promote international action to reduce marine debris, and for other purposes.",
#                     "question": "On the Motion",
#                     "result": "Motion Agreed to",
#                     "date": "2018-12-18",
#                     "time": "20:22:00",
#                     "total": {
#                         "yes": 87,
#                         "no": 12,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "270",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/270.json",
#                     "bill": {
#                         "bill_id": "s756-115",
#                         "number": "S. 756",
#                         "sponsor_id": "S001198",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/s756.json",
#                         "title": "A bill to reauthorize and amend the Marine Debris Act to promote international action to reduce marine debris, and for other purposes.",
#                         "latest_action": "Signed by President."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 4109 to S.Amdt. 4108",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt4109.json",
#                         "sponsor_id": "K000393",
#                         "sponsor": "John Kennedy",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/K000393.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "La."
#                     },
#                     "description": "To require the Director of the Bureau of Prisons to notify each victim of the offense for which the prisoner is imprisoned the date on which the prisoner will be ...",
#                     "question": "On the Amendment",
#                     "result": "Amendment Rejected",
#                     "date": "2018-12-18",
#                     "time": "20:02:00",
#                     "total": {
#                         "yes": 37,
#                         "no": 62,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "269",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/269.json",
#                     "bill": {
#                         "bill_id": "s756-115",
#                         "number": "S. 756",
#                         "sponsor_id": "S001198",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/s756.json",
#                         "title": "A bill to reauthorize and amend the Marine Debris Act to promote international action to reduce marine debris, and for other purposes.",
#                         "latest_action": "Signed by President."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 4109 to S.Amdt. 4108",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt4109.json",
#                         "sponsor_id": "K000393",
#                         "sponsor": "John Kennedy",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/K000393.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "La."
#                     },
#                     "description": "To require the Director of the Bureau of Prisons to notify each victim of the offense for which the prisoner is imprisoned the date on which the prisoner will be ...",
#                     "question": "On the Amendment",
#                     "result": "Amendment Rejected",
#                     "date": "2018-12-18",
#                     "time": "19:43:00",
#                     "total": {
#                         "yes": 33,
#                         "no": 66,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "268",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/268.json",
#                     "bill": {
#                         "bill_id": "s756-115",
#                         "number": "S. 756",
#                         "sponsor_id": "S001198",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/s756.json",
#                         "title": "A bill to reauthorize and amend the Marine Debris Act to promote international action to reduce marine debris, and for other purposes.",
#                         "latest_action": "Signed by President."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 4109 to S.Amdt. 4108",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt4109.json",
#                         "sponsor_id": "K000393",
#                         "sponsor": "John Kennedy",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/K000393.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "La."
#                     },
#                     "description": "To require the Director of the Bureau of Prisons to notify each victim of the offense for which the prisoner is imprisoned the date on which the prisoner will be ...",
#                     "question": "On the Amendment",
#                     "result": "Amendment Rejected",
#                     "date": "2018-12-18",
#                     "time": "19:01:00",
#                     "total": {
#                         "yes": 32,
#                         "no": 67,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "267",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/267.json",
#                     "bill": {
#                         "bill_id": "s756-115",
#                         "number": "S.756",
#                         "sponsor_id": "S001198",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/s756.json",
#                         "title": "A bill to reauthorize and amend the Marine Debris Act to promote international action to reduce marine debris, and for other purposes.",
#                         "latest_action": "Signed by President."
#                     },
#                     "amendment": {},
#                     "description": "A bill to reauthorize and amend the Marine Debris Act to promote international action to reduce marine debris, and for other purposes.",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-12-17",
#                     "time": "17:22:00",
#                     "total": {
#                         "yes": 82,
#                         "no": 12,
#                         "present": 0,
#                         "not_voting": 6
#                     },
#                     "position": "Not Voting"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "266",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/266.json",
#                     "bill": {
#                         "bill_id": "sjres54-115",
#                         "number": "S.J.Res.54",
#                         "sponsor_id": "S000033",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/sjres54.json",
#                         "title": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                         "latest_action": "Held at the desk."
#                     },
#                     "amendment": {},
#                     "description": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                     "question": "On the Joint Resolution",
#                     "result": "Joint Resolution Passed",
#                     "date": "2018-12-13",
#                     "time": "15:03:00",
#                     "total": {
#                         "yes": 56,
#                         "no": 41,
#                         "present": 0,
#                         "not_voting": 3
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "265",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/265.json",
#                     "bill": {
#                         "bill_id": "sjres54-115",
#                         "number": "S.J.Res. 54",
#                         "sponsor_id": "S000033",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/sjres54.json",
#                         "title": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                         "latest_action": "Held at the desk."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 4098",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt4098.json",
#                         "sponsor_id": "C001095",
#                         "sponsor": "Tom Cotton",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/C001095.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "Ark."
#                     },
#                     "description": "To clarify that the requirement to remove United States Armed Forces does not apply to forces engaged in operations to support efforts to disrupt Houthi attacks against locations outside of ...",
#                     "question": "On the Amendment",
#                     "result": "Amendment Rejected",
#                     "date": "2018-12-13",
#                     "time": "14:45:00",
#                     "total": {
#                         "yes": 45,
#                         "no": 54,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "264",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/264.json",
#                     "bill": {
#                         "bill_id": "sjres54-115",
#                         "number": "S.J.Res. 54",
#                         "sponsor_id": "S000033",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/sjres54.json",
#                         "title": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                         "latest_action": "Held at the desk."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 4096",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt4096.json",
#                         "sponsor_id": "C001056",
#                         "sponsor": "John Cornyn",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/C001056.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "Tex."
#                     },
#                     "description": "To provide that nothing in the joint resolution shall be construed to influence or disrupt any military operations and cooperation with Israel.",
#                     "question": "On the Amendment",
#                     "result": "Amendment Agreed to",
#                     "date": "2018-12-13",
#                     "time": "14:21:00",
#                     "total": {
#                         "yes": 99,
#                         "no": 0,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "263",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/263.json",
#                     "bill": {
#                         "bill_id": "sjres54-115",
#                         "number": "S.J.Res. 54",
#                         "sponsor_id": "S000033",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/sjres54.json",
#                         "title": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                         "latest_action": "Held at the desk."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 4080",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt4080.json",
#                         "sponsor_id": "Y000064",
#                         "sponsor": "Todd Young",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/Y000064.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "Ind."
#                     },
#                     "description": "To clarify that this resolution prohibits United States Armed Forces from refueling non-United States aircraft conducting missions as part of the ongoing civil war in Yemen.",
#                     "question": "On the Amendment",
#                     "result": "Amendment Agreed to",
#                     "date": "2018-12-13",
#                     "time": "13:50:00",
#                     "total": {
#                         "yes": 58,
#                         "no": 41,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "262",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/262.json",
#                     "bill": {
#                         "bill_id": "sjres54-115",
#                         "number": "S.J.Res.54",
#                         "sponsor_id": "S000033",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/sjres54.json",
#                         "title": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                         "latest_action": "Held at the desk."
#                     },
#                     "amendment": {},
#                     "description": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                     "question": "On the Point of Order",
#                     "result": "Point of Order Well Taken",
#                     "date": "2018-12-12",
#                     "time": "15:40:00",
#                     "total": {
#                         "yes": 96,
#                         "no": 3,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "261",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/261.json",
#                     "bill": {
#                         "bill_id": "sjres54-115",
#                         "number": "S.J.Res.54",
#                         "sponsor_id": "S000033",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/sjres54.json",
#                         "title": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                         "latest_action": "Held at the desk."
#                     },
#                     "amendment": {},
#                     "description": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                     "question": "On the Motion to Proceed",
#                     "result": "Motion to Proceed Agreed to",
#                     "date": "2018-12-12",
#                     "time": "14:57:00",
#                     "total": {
#                         "yes": 60,
#                         "no": 39,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "260",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/260.json",
#                     "bill": {
#                         "bill_id": "sjres64-115",
#                         "number": "S.J.Res.64",
#                         "sponsor_id": "T000464",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/sjres64.json",
#                         "title": "A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Department of the Treasury relating to &quot;Returns by Exempt Organizations and Returns by Certain Non-Exempt Organizations&quot;.",
#                         "latest_action": "Held at the desk."
#                     },
#                     "amendment": {},
#                     "description": "A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Department of the Treasury relating to &quot;Returns by ...",
#                     "question": "On the Joint Resolution",
#                     "result": "Joint Resolution Passed",
#                     "date": "2018-12-12",
#                     "time": "12:27:00",
#                     "total": {
#                         "yes": 50,
#                         "no": 49,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "259",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/259.json",
#                     "bill": {
#                         "bill_id": "hr2-115",
#                         "number": "H.R.2",
#                         "sponsor_id": "C001062",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/hr2.json",
#                         "title": "To provide for the reform and continuation of agricultural and other programs of the Department of Agriculture through fiscal year 2023, and for other purposes.",
#                         "latest_action": "Became Public Law No: 115-334."
#                     },
#                     "amendment": {},
#                     "description": "A bill to provide for the reform and continuation of agricultural and other programs of the Department of Agriculture through fiscal year 2023, and for other purposes.",
#                     "question": "On the Conference Report",
#                     "result": "Conference Report Agreed to",
#                     "date": "2018-12-11",
#                     "time": "15:58:00",
#                     "total": {
#                         "yes": 87,
#                         "no": 13,
#                         "present": 0,
#                         "not_voting": 0
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "258",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/258.json",
#                     "bill": {
#                         "bill_id": "pn2117-115",
#                         "number": "PN2117",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2117-115",
#                         "number": "PN2117",
#                         "name": "Jonathan A. Kobes",
#                         "agency": "The Judiciary"
#                     },
#                     "description": "Jonathan A. Kobes, of South Dakota, to be United States Circuit Judge for the Eighth Circuit",
#                     "question": "On the Nomination",
#                     "result": "Nomination Confirmed",
#                     "date": "2018-12-11",
#                     "time": "14:17:00",
#                     "total": {
#                         "yes": 50,
#                         "no": 50,
#                         "present": 0,
#                         "not_voting": 0
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "257",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/257.json",
#                     "bill": {
#                         "bill_id": "pn1803-115",
#                         "number": "PN1803",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN1803-115",
#                         "number": "PN1803",
#                         "name": "Justin George Muzinich",
#                         "agency": "Department of the Treasury"
#                     },
#                     "description": "Justin George Muzinich, of New York, to be Deputy Secretary of the Treasury",
#                     "question": "On the Nomination",
#                     "result": "Nomination Confirmed",
#                     "date": "2018-12-11",
#                     "time": "11:00:00",
#                     "total": {
#                         "yes": 55,
#                         "no": 44,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "256",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/256.json",
#                     "bill": {
#                         "bill_id": "pn1803-115",
#                         "number": "PN1803",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN1803-115",
#                         "number": "PN1803",
#                         "name": "Justin George Muzinich",
#                         "agency": "Department of the Treasury"
#                     },
#                     "description": "Justin George Muzinich, of New York, to be Deputy Secretary of the Treasury",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-12-10",
#                     "time": "17:32:00",
#                     "total": {
#                         "yes": 55,
#                         "no": 43,
#                         "present": 0,
#                         "not_voting": 2
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "255",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/255.json",
#                     "bill": {
#                         "bill_id": "pn2170-115",
#                         "number": "PN2170",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2170-115",
#                         "number": "PN2170",
#                         "name": "Kathleen Laura Kraninger",
#                         "agency": "Bureau of Consumer Financial Protection"
#                     },
#                     "description": "Kathleen Laura Kraninger, of Ohio, to be Director, Bureau of Consumer Financial Protection for a term of five years",
#                     "question": "On the Nomination",
#                     "result": "Nomination Confirmed",
#                     "date": "2018-12-06",
#                     "time": "13:34:00",
#                     "total": {
#                         "yes": 50,
#                         "no": 49,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 }
#             ]
#         }
#     ]
# }
# {
#     "status": "OK",
#     "copyright": "Copyright (c) 2018 Pro Publica Inc. All Rights Reserved.",
#     "results": [
#         {
#             "member_id": "A000360",
#             "num_results": "20",
#             "offset": "20",
#             "votes": [
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "254",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/254.json",
#                     "bill": {
#                         "bill_id": "pn2556-115",
#                         "number": "PN2556",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2556-115",
#                         "number": "PN2556",
#                         "name": "Bernard L. McNamee",
#                         "agency": "Federal Energy Regulatory Commission"
#                     },
#                     "description": "Bernard L. McNamee, of Virginia, to be a Member of the Federal Energy Regulatory Commission for the remainder of the term expiring June 30, 2020",
#                     "question": "On the Nomination",
#                     "result": "Nomination Confirmed",
#                     "date": "2018-12-06",
#                     "time": "12:00:00",
#                     "total": {
#                         "yes": 50,
#                         "no": 49,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "253",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/253.json",
#                     "bill": {
#                         "bill_id": "pn2556-115",
#                         "number": "PN2556",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2556-115",
#                         "number": "PN2556",
#                         "name": "Bernard L. McNamee",
#                         "agency": "Federal Energy Regulatory Commission"
#                     },
#                     "description": "Bernard L. McNamee, of Virginia, to be a Member of the Federal Energy Regulatory Commission for the remainder of the term expiring June 30, 2020",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-12-05",
#                     "time": "16:05:00",
#                     "total": {
#                         "yes": 50,
#                         "no": 49,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "252",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/252.json",
#                     "bill": {
#                         "bill_id": "pn2170-115",
#                         "number": "PN2170",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2170-115",
#                         "number": "PN2170",
#                         "name": "Kathleen Laura Kraninger",
#                         "agency": "Bureau of Consumer Financial Protection"
#                     },
#                     "description": "Kathleen Laura Kraninger, of Ohio, to be Director, Bureau of Consumer Financial Protection for a term of five years",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-11-29",
#                     "time": "13:28:00",
#                     "total": {
#                         "yes": 50,
#                         "no": 49,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "251",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/251.json",
#                     "bill": {
#                         "bill_id": "pn2117-115",
#                         "number": "PN2117",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2117-115",
#                         "number": "PN2117",
#                         "name": "Jonathan A. Kobes",
#                         "agency": "The Judiciary"
#                     },
#                     "description": "Jonathan A. Kobes, of South Dakota, to be United States Circuit Judge for the Eighth Circuit",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-11-29",
#                     "time": "12:14:00",
#                     "total": {
#                         "yes": 49,
#                         "no": 49,
#                         "present": 1,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "250",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/250.json",
#                     "bill": {
#                         "bill_id": "sjres54-115",
#                         "number": "S.J.Res.54",
#                         "sponsor_id": "S000033",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/sjres54.json",
#                         "title": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                         "latest_action": "Held at the desk."
#                     },
#                     "amendment": {},
#                     "description": "A joint resolution to direct the removal of United States Armed Forces from hostilities in the Republic of Yemen that have not been authorized by Congress.",
#                     "question": "On the Motion to Discharge",
#                     "result": "Motion to Discharge Agreed to",
#                     "date": "2018-11-28",
#                     "time": "15:52:00",
#                     "total": {
#                         "yes": 63,
#                         "no": 37,
#                         "present": 0,
#                         "not_voting": 0
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "249",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/249.json",
#                     "bill": {
#                         "bill_id": "pn1412-115",
#                         "number": "PN1412",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN1412-115",
#                         "number": "PN1412",
#                         "name": "Thomas Alvin Farr",
#                         "agency": "The Judiciary"
#                     },
#                     "description": "Thomas Alvin Farr, of North Carolina, to be United States District Judge for the Eastern District of North Carolina",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-11-28",
#                     "time": "12:56:00",
#                     "total": {
#                         "yes": 50,
#                         "no": 50,
#                         "present": 0,
#                         "not_voting": 0
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "248",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/248.json",
#                     "bill": {
#                         "bill_id": "pn2049-115",
#                         "number": "PN2049",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2049-115",
#                         "number": "PN2049",
#                         "name": "Karen Dunn Kelley",
#                         "agency": "Department of Commerce"
#                     },
#                     "description": "Karen Dunn Kelley, of Pennsylvania, to be Deputy Secretary of Commerce",
#                     "question": "On the Nomination",
#                     "result": "Nomination Confirmed",
#                     "date": "2018-11-28",
#                     "time": "12:19:00",
#                     "total": {
#                         "yes": 62,
#                         "no": 38,
#                         "present": 0,
#                         "not_voting": 0
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "247",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/247.json",
#                     "bill": {
#                         "bill_id": "pn2049-115",
#                         "number": "PN2049",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN2049-115",
#                         "number": "PN2049",
#                         "name": "Karen Dunn Kelley",
#                         "agency": "Department of Commerce"
#                     },
#                     "description": "Karen Dunn Kelley, of Pennsylvania, to be Deputy Secretary of Commerce",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-11-27",
#                     "time": "12:54:00",
#                     "total": {
#                         "yes": 62,
#                         "no": 37,
#                         "present": 0,
#                         "not_voting": 1
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "246",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/246.json",
#                     "bill": {
#                         "bill_id": "pn889-115",
#                         "number": "PN889",
#                         "api_uri": null,
#                         "title": null,
#                         "latest_action": null
#                     },
#                     "amendment": {},
#                     "nomination": {
#                         "nomination_id": "PN889-115",
#                         "number": "PN889",
#                         "name": "Stephen Alexander Vaden",
#                         "agency": "Department of Agriculture"
#                     },
# ...
#                     "amendment": {},
#                     "description": "A bill making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.",
#                     "question": "On Passage of the Bill",
#                     "result": "Bill Passed",
#                     "date": "2018-08-01",
#                     "time": "13:06:00",
#                     "total": {
#                         "yes": 92,
#                         "no": 6,
#                         "present": 0,
#                         "not_voting": 2
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "179",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/179.json",
#                     "bill": {
#                         "bill_id": "hr6147-115",
#                         "number": "H.R. 6147",
#                         "sponsor_id": "C000059",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/hr6147.json",
#                         "title": "Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.",
#                         "latest_action": "Message on Senate action sent to the House."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 3402 to S.Amdt. 3399",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt3402.json",
#                         "sponsor_id": "C001098",
#                         "sponsor": "Ted Cruz",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/C001098.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "Tex."
#                     },
#                     "description": "To prohibit the use of funds to carry out the District of Columbia&#39;s health insurance individual mandate.",
#                     "question": "On the Motion to Table",
#                     "result": "Motion to Table Agreed to",
#                     "date": "2018-08-01",
#                     "time": "12:39:00",
#                     "total": {
#                         "yes": 54,
#                         "no": 44,
#                         "present": 0,
#                         "not_voting": 2
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "178",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/178.json",
#                     "bill": {
#                         "bill_id": "hr6147-115",
#                         "number": "H.R. 6147",
#                         "sponsor_id": "C000059",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/hr6147.json",
#                         "title": "Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.",
#                         "latest_action": "Message on Senate action sent to the House."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 3524 to S.Amdt. 3399",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt3524.json",
#                         "sponsor_id": "B001230",
#                         "sponsor": "Tammy Baldwin",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/B001230.json",
#                         "sponsor_party": "D",
#                         "sponsor_state": "Wis."
#                     },
#                     "description": "To appropriate funds to carry out programs relating to the innovation, process improvement, and marketing of dairy products.",
#                     "question": "On the Amendment",
#                     "result": "Amendment Agreed to",
#                     "date": "2018-08-01",
#                     "time": "12:15:00",
#                     "total": {
#                         "yes": 83,
#                         "no": 15,
#                         "present": 0,
#                         "not_voting": 2
#                     },
#                     "position": "Yes"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "177",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/177.json",
#                     "bill": {
#                         "bill_id": "hr6147-115",
#                         "number": "H.R. 6147",
#                         "sponsor_id": "C000059",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/hr6147.json",
#                         "title": "Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.",
#                         "latest_action": "Message on Senate action sent to the House."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 3522 to S.Amdt. 3399",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt3522.json",
#                         "sponsor_id": "L000577",
#                         "sponsor": "Mike Lee",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/L000577.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "Utah"
#                     },
#                     "description": "To prohibit the use of funds to enforce standards of identity with respect to certain food.",
#                     "question": "On the Amendment",
#                     "result": "Amendment Rejected",
#                     "date": "2018-08-01",
#                     "time": "11:50:00",
#                     "total": {
#                         "yes": 14,
#                         "no": 84,
#                         "present": 0,
#                         "not_voting": 2
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "176",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/176.json",
#                     "bill": {
#                         "bill_id": "hr6147-115",
#                         "number": "H.R. 6147",
#                         "sponsor_id": "C000059",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/hr6147.json",
#                         "title": "Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.",
#                         "latest_action": "Message on Senate action sent to the House."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 3464 to S.Amdt. 3399",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt3464.json",
#                         "sponsor_id": "L000174",
#                         "sponsor": "Patrick J. Leahy",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/L000174.json",
#                         "sponsor_party": "D",
#                         "sponsor_state": "Vt."
#                     },
#                     "description": "To provide for election security grants.",
#                     "question": "On the Amendment",
#                     "result": "Amendment Rejected",
#                     "date": "2018-08-01",
#                     "time": "11:07:00",
#                     "total": {
#                         "yes": 50,
#                         "no": 47,
#                         "present": 0,
#                         "not_voting": 3
#                     },
#                     "position": "No"
#                 },
#                 {
#                     "member_id": "A000360",
#                     "chamber": "Senate",
#                     "congress": "115",
#                     "session": "2",
#                     "roll_call": "175",
#                     "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/2/votes/175.json",
#                     "bill": {
#                         "bill_id": "hr6147-115",
#                         "number": "H.R. 6147",
#                         "sponsor_id": "C000059",
#                         "bill_uri": "https://api.propublica.org/congress/v1/115/bills/hr6147.json",
#                         "title": "Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.",
#                         "latest_action": "Message on Senate action sent to the House."
#                     },
#                     "amendment": {
#                         "number": "S.Amdt. 3399",
#                         "api_uri": "https://api.propublica.org/congress/v1/115/amendments/samdt3399.json",
#                         "sponsor_id": "S000320",
#                         "sponsor": "Richard C. Shelby",
#                         "sponsor_uri": "https://api.propublica.org/congress/v1/members/S000320.json",
#                         "sponsor_party": "R",
#                         "sponsor_state": "Ala."
#                     },
#                     "description": "In the nature of a substitute.",
#                     "question": "On the Cloture Motion",
#                     "result": "Cloture Motion Agreed to",
#                     "date": "2018-07-31",
#                     "time": "14:46:00",
#                     "total": {
#                         "yes": 94,
#                         "no": 4,
#                         "present": 0,
#                         "not_voting": 2
#                     },
#                     "position": "Yes"
#                 }
#             ]
#         }
#     ]
# }
# A000360 offset: 80
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Programs\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0eace6253264> in <module>()
#      18
#      19     while data_available :
# ---> 20         res = requests.get(url = u.format(member_id = senator_id, offset = request_offset), headers = HEADERS)
#      21         s = re.sub(r'(\s{2,}|\n)', ' ', res.text)
#      22
#
# D:\Programs\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\Programs\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\Programs\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# D:\Programs\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# D:\Programs\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     443                     decode_content=False,
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#     447
#
# D:\Programs\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# D:\Programs\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# D:\Programs\Anaconda\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# D:\Programs\Anaconda\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# D:\Programs\Anaconda\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# D:\Programs\Anaconda\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# D:\Programs\Anaconda\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     283     def recv_into(self, *args, **kwargs):
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#     287             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# D:\Programs\Anaconda\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %% [markdown]
# # Fetching Lobbying from senate (unused in project)

# %%
re.compile("\((.*)\"([\w ]+)\"(.*)\)")

# %%
# Request config
u = "https://api.propublica.org/congress/v1/lobbying/latest.json?offset={offset}"

votes_list = []
data_available = True
request_offset = 0

while data_available :
    res = requests.get(url = u.format(offset = request_offset), headers = HEADERS)
    j  = res.text.replace("\\\"","").replace("\\","").replace("\")", ")").replace("(\"", "(")

    try:
        res = json.loads(j)       
        if('results' in res):
            #print(request_offset)
            data_available = int(res['results'][0]['num_results']) > 0

            if data_available:
                votes = res['results'][0]['lobbying_representations']
                votes_list.append(pd.io.json.json_normalize(votes, record_prefix=True))
        else:
            print(str(request_offset) + ' - Error: ' + res['error'])
    except:
        print(str(request_offset) + ' - Error: Json File badly encoded')
    request_offset += 20
    
df = pd.concat(votes_list,sort=True)
df.to_csv(data_folder + "lobby/lobby.csv")
df.head()
