# %%
import pandas as pd
import numpy as np
import requests
import json
print(pd.__version__)
# Out:
# 0.23.0

# %%
API_KEY = ""

with open('api_key.txt') as f:
    API_KEY = f.read()
    
print("API key: "+API_KEY)

HEADERS = {"X-Api-Key": API_KEY}
# Out:
# API key: OoD35vcgzdv2xXYUA3TwEGRY6yt1UN24W4nsIhU9

# %%
# Request config
req_str = "https://api.propublica.org/congress/v1/senate/votes/recent.json?offset={offset}"

res = requests.get(req_str.format(offset=460), headers = HEADERS)

print(json.dumps(res.json(), indent=4))
# Out:
# {
#     "status": "OK",
#     "copyright": "Copyright (c) 2018 Pro Publica Inc. All Rights Reserved.",
#     "results": {
#         "chamber": "Senate",
#         "offset": 460,
#         "num_results": 20,
#         "votes": [
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 84,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00084.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00084",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/84.json",
#                 "bill": {
#                     "bill_id": "hjres57-115",
#                     "number": "H.J.RES.57",
#                     "sponsor_id": "R000592",
#                     "api_uri": "https://api.propublica.org/congress/v1/115/bills/hjres57.json",
#                     "title": "Providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Department of Education relating to accountability and State plans under the Elementary and Secondary Education Act of 1965.",
#                     "latest_action": "Became Public Law No: 115-13."
#                 },
#                 "amendment": {},
#                 "question": "On the Joint Resolution",
#                 "description": "A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Department of Education relating to accountability and State plans under the Elementary and Secondary Education Act of 1965.",
#                 "vote_type": "1/2",
#                 "date": "2017-03-09",
#                 "time": "12:02:00",
#                 "result": "Joint Resolution Passed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 0,
#                     "no": 46,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 50,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 0,
#                     "no": 2,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 50,
#                     "no": 49,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 83,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00083.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00083",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/83.json",
#                 "bill": {
#                     "bill_id": "hjres58-115",
#                     "number": "H.J.RES.58",
#                     "sponsor_id": "G000558",
#                     "api_uri": "https://api.propublica.org/congress/v1/115/bills/hjres58.json",
#                     "title": "Providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Department of Education relating to teacher preparation issues.",
#                     "latest_action": "Became Public Law No: 115-14."
#                 },
#                 "amendment": {},
#                 "question": "On the Joint Resolution",
#                 "description": "A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Department of Education relating to teacher preparation issues.",
#                 "vote_type": "1/2",
#                 "date": "2017-03-08",
#                 "time": "14:30:00",
#                 "result": "Joint Resolution Passed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 7,
#                     "no": 39,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 59,
#                     "no": 40,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 82,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00082.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00082",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/82.json",
#                 "bill": {
#                     "bill_id": "hjres44-115",
#                     "number": "H.J.RES.44",
#                     "sponsor_id": "C001109",
#                     "api_uri": "https://api.propublica.org/congress/v1/115/bills/hjres44.json",
#                     "title": "Disapproving the rule submitted by the Department of the Interior relating to Bureau of Land Management regulations that establish the procedures used to prepare, revise, or amend land use plans pursuant to the Federal Land Policy and Management Act of 1976.",
#                     "latest_action": "Became Public Law No: 115-12."
#                 },
#                 "amendment": {},
#                 "question": "On the Joint Resolution",
#                 "description": "A joint resolution disapproving the rule submitted by the Department of the Interior relating to Bureau of Land Management regulations that establish the procedures used to prepare, revise, or amend land use plans pursuant to the Federal Land Policy and Management Act of 1976.",
#                 "vote_type": "1/2",
#                 "date": "2017-03-07",
#                 "time": "15:59:00",
#                 "result": "Joint Resolution Passed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 0,
#                     "no": 46,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 0,
#                     "no": 2,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 51,
#                     "no": 48,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 81,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00081.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00081",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/81.json",
#                 "bill": {
#                     "bill_id": "hjres37-115",
#                     "number": "H.J.RES.37",
#                     "sponsor_id": "F000450",
#                     "api_uri": "https://api.propublica.org/congress/v1/115/bills/hjres37.json",
#                     "title": "Disapproving the rule submitted by the Department of Defense, the General Services Administration, and the National Aeronautics and Space Administration relating to the Federal Acquisition Regulation.",
#                     "latest_action": "Became Public Law No: 115-11."
#                 },
#                 "amendment": {},
#                 "question": "On the Joint Resolution",
#                 "description": "A joint resolution disapproving the rule submitted by the Department of Defense, the General Services Administration, and the National Aeronautics and Space Administration relating to the Federal Acquisition Regulation.",
#                 "vote_type": "1/2",
#                 "date": "2017-03-06",
#                 "time": "18:02:00",
#                 "result": "Joint Resolution Passed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 0,
#                     "no": 46,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 49,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 3,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 0,
#                     "no": 2,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 49,
#                     "no": 48,
#                     "present": 0,
#                     "not_voting": 3
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 80,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00080.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00080",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/80.json",
#                 "bill": {
#                     "bill_id": "hjres37-115",
#                     "number": "H.J.RES.37",
#                     "sponsor_id": "F000450",
#                     "api_uri": "https://api.propublica.org/congress/v1/115/bills/hjres37.json",
#                     "title": "Disapproving the rule submitted by the Department of Defense, the General Services Administration, and the National Aeronautics and Space Administration relating to the Federal Acquisition Regulation.",
#                     "latest_action": "Became Public Law No: 115-11."
#                 },
#                 "amendment": {},
#                 "question": "On the Motion to Proceed",
#                 "description": "A joint resolution disapproving the rule submitted by the Department of Defense, the General Services Administration, and the National Aeronautics and Space Administration relating to the Federal Acquisition Regulation.",
#                 "vote_type": "1/2",
#                 "date": "2017-03-02",
#                 "time": "14:12:00",
#                 "result": "Motion to Proceed Agreed to",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 0,
#                     "no": 44,
#                     "present": 0,
#                     "not_voting": 2,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 0,
#                     "no": 2,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 51,
#                     "no": 46,
#                     "present": 0,
#                     "not_voting": 3
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 79,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00079.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00079",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/79.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN36-115",
#                     "number": "PN36",
#                     "name": "James Richard Perry",
#                     "agency": "Department of Energy"
#                 },
#                 "question": "On the Nomination",
#                 "description": "James Richard Perry, of Texas, to be Secretary of Energy",
#                 "vote_type": "1/2",
#                 "date": "2017-03-02",
#                 "time": "13:46:00",
#                 "result": "Nomination Confirmed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 10,
#                     "no": 36,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 62,
#                     "no": 37,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 78,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00078.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00078",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/78.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN36-115",
#                     "number": "PN36",
#                     "name": "James Richard Perry",
#                     "agency": "Department of Energy"
#                 },
#                 "question": "On the Cloture Motion",
#                 "description": "James Richard Perry, of Texas, to be Secretary of Energy",
#                 "vote_type": "1/2",
#                 "date": "2017-03-02",
#                 "time": "10:34:00",
#                 "result": "Cloture Motion Agreed to",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 10,
#                     "no": 36,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 62,
#                     "no": 37,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 77,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00077.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00077",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/77.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN34-115",
#                     "number": "PN34",
#                     "name": "Benjamin S. Carson Sr.",
#                     "agency": "Department of Housing and Urban Development"
#                 },
#                 "question": "On the Nomination",
#                 "description": "Benjamin S. Carson, Sr., of Florida, to be Secretary of Housing and Urban Development",
#                 "vote_type": "1/2",
#                 "date": "2017-03-02",
#                 "time": "10:02:00",
#                 "result": "Nomination Confirmed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 6,
#                     "no": 40,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 58,
#                     "no": 41,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 76,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00076.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00076",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/76.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN34-115",
#                     "number": "PN34",
#                     "name": "Benjamin S. Carson Sr.",
#                     "agency": "Department of Housing and Urban Development"
#                 },
#                 "question": "On the Cloture Motion",
#                 "description": "Benjamin S. Carson, Sr., of Florida, to be Secretary of Housing and Urban Development",
#                 "vote_type": "1/2",
#                 "date": "2017-03-01",
#                 "time": "11:06:00",
#                 "result": "Cloture Motion Agreed to",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 10,
#                     "no": 36,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 62,
#                     "no": 37,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 75,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00075.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00075",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/75.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN31-115",
#                     "number": "PN31",
#                     "name": "Ryan Zinke",
#                     "agency": "Department of the Interior"
#                 },
#                 "question": "On the Nomination",
#                 "description": "Ryan Zinke, of Montana, to be Secretary of the Interior",
#                 "vote_type": "1/2",
#                 "date": "2017-03-01",
#                 "time": "10:33:00",
#                 "result": "Nomination Confirmed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 16,
#                     "no": 30,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 68,
#                     "no": 31,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 74,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00074.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00074",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/74.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN31-115",
#                     "number": "PN31",
#                     "name": "Ryan Zinke",
#                     "agency": "Department of the Interior"
#                 },
#                 "question": "On the Cloture Motion",
#                 "description": "Ryan Zinke, of Montana, to be Secretary of the Interior",
#                 "vote_type": "1/2",
#                 "date": "2017-02-28",
#                 "time": "19:32:00",
#                 "result": "Cloture Motion Agreed to",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 15,
#                     "no": 30,
#                     "present": 1,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 67,
#                     "no": 31,
#                     "present": 1,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 73,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00073.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00073",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/73.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN32-115",
#                     "number": "PN32",
#                     "name": "Wilbur L. Ross Jr.",
#                     "agency": "Department of Commerce"
#                 },
#                 "question": "On the Nomination",
#                 "description": "Wilbur L. Ross, Jr., of Florida, to be Secretary of Commerce",
#                 "vote_type": "1/2",
#                 "date": "2017-02-28",
#                 "time": "19:01:00",
#                 "result": "Nomination Confirmed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 20,
#                     "no": 26,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 72,
#                     "no": 27,
#                     "present": 0,
#                     "not_voting": 1
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 72,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00072.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00072",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/72.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN32-115",
#                     "number": "PN32",
#                     "name": "Wilbur L. Ross Jr.",
#                     "agency": "Department of Commerce"
#                 },
#                 "question": "On the Cloture Motion",
#                 "description": "Wilbur L. Ross, Jr., of Florida, to be Secretary of Commerce",
#                 "vote_type": "1/2",
#                 "date": "2017-02-17",
#                 "time": "13:17:00",
#                 "result": "Cloture Motion Agreed to",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 15,
#                     "no": 30,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 50,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 2,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 66,
#                     "no": 31,
#                     "present": 0,
#                     "not_voting": 3
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 71,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00071.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00071",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/71.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN44-115",
#                     "number": "PN44",
#                     "name": "Scott Pruitt",
#                     "agency": "Environmental Protection Agency"
#                 },
#                 "question": "On the Nomination",
#                 "description": "Scott Pruitt, of Oklahoma, to be Administrator of the Environmental Protection Agency",
#                 "vote_type": "1/2",
#                 "date": "2017-02-17",
#                 "time": "13:03:00",
#                 "result": "Nomination Confirmed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 2,
#                     "no": 43,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 50,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 0,
#                     "no": 2,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 52,
#                     "no": 46,
#                     "present": 0,
#                     "not_voting": 2
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 70,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00070.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00070",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/70.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN44-115",
#                     "number": "PN44",
#                     "name": "Scott Pruitt",
#                     "agency": "Environmental Protection Agency"
#                 },
#                 "question": "On the Motion",
#                 "description": "Scott Pruitt, of Oklahoma, to be Administrator of the Environmental Protection Agency",
#                 "vote_type": "3/5",
#                 "date": "2017-02-17",
#                 "time": "12:35:00",
#                 "result": "Motion Rejected",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 45,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "Yes"
#                 },
#                 "republican": {
#                     "yes": 0,
#                     "no": 51,
#                     "present": 0,
#                     "not_voting": 1,
#                     "majority_position": "No"
#                 },
#                 "independent": {
#                     "yes": 2,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 47,
#                     "no": 51,
#                     "present": 0,
#                     "not_voting": 2
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 69,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00069.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00069",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/69.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN44-115",
#                     "number": "PN44",
#                     "name": "Scott Pruitt",
#                     "agency": "Environmental Protection Agency"
#                 },
#                 "question": "On the Cloture Motion",
#                 "description": "Scott Pruitt, of Oklahoma, to be Administrator of the Environmental Protection Agency",
#                 "vote_type": "1/2",
#                 "date": "2017-02-16",
#                 "time": "11:16:00",
#                 "result": "Cloture Motion Agreed to",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 2,
#                     "no": 44,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 52,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 0,
#                     "no": 2,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 54,
#                     "no": 46,
#                     "present": 0,
#                     "not_voting": 0
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 68,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00068.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00068",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/68.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN54-115",
#                     "number": "PN54",
#                     "name": "Mick Mulvaney",
#                     "agency": "Executive Office of the President"
#                 },
#                 "question": "On the Nomination",
#                 "description": "Mick Mulvaney, of South Carolina, to be Director of the Office of Management and Budget",
#                 "vote_type": "1/2",
#                 "date": "2017-02-16",
#                 "time": "10:42:00",
#                 "result": "Nomination Confirmed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 0,
#                     "no": 46,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 51,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 0,
#                     "no": 2,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 51,
#                     "no": 49,
#                     "present": 0,
#                     "not_voting": 0
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 67,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00067.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00067",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/67.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN54-115",
#                     "number": "PN54",
#                     "name": "Mick Mulvaney",
#                     "agency": "Executive Office of the President"
#                 },
#                 "question": "On the Cloture Motion",
#                 "description": "Mick Mulvaney, of South Carolina, to be Director of the Office of Management and Budget",
#                 "vote_type": "1/2",
#                 "date": "2017-02-15",
#                 "time": "11:04:00",
#                 "result": "Cloture Motion Agreed to",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 0,
#                     "no": 46,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 52,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 0,
#                     "no": 2,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 52,
#                     "no": 48,
#                     "present": 0,
#                     "not_voting": 0
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 66,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00066.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00066",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/66.json",
#                 "bill": {
#                     "bill_id": "hjres40-115",
#                     "number": "H.J.RES.40",
#                     "sponsor_id": "J000174",
#                     "api_uri": "https://api.propublica.org/congress/v1/115/bills/hjres40.json",
#                     "title": "Providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Social Security Administration relating to Implementation of the NICS Improvement Amendments Act of 2007.",
#                     "latest_action": "Became Public Law No: 115-8."
#                 },
#                 "amendment": {},
#                 "question": "On the Joint Resolution",
#                 "description": "A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Social Security Administration relating to Implementation of the NICS Improvement Amendments Act of 2007.",
#                 "vote_type": "1/2",
#                 "date": "2017-02-15",
#                 "time": "10:31:00",
#                 "result": "Joint Resolution Passed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 4,
#                     "no": 42,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "No"
#                 },
#                 "republican": {
#                     "yes": 52,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 57,
#                     "no": 43,
#                     "present": 0,
#                     "not_voting": 0
#                 }
#             },
#             {
#                 "congress": 115,
#                 "chamber": "Senate",
#                 "session": 1,
#                 "roll_call": 65,
#                 "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1151/vote_115_1_00065.xml",
#                 "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=115&session=1&vote=00065",
#                 "vote_uri": "https://api.propublica.org/congress/v1/115/senate/sessions/1/votes/65.json",
#                 "bill": {},
#                 "amendment": {},
#                 "nomination": {
#                     "nomination_id": "PN48-115",
#                     "number": "PN48",
#                     "name": "Linda E. McMahon",
#                     "agency": "Small Business Administration"
#                 },
#                 "question": "On the Nomination",
#                 "description": "Linda E. McMahon, of Connecticut, to be Administrator of the Small Business Administration",
#                 "vote_type": "1/2",
#                 "date": "2017-02-14",
#                 "time": "11:01:00",
#                 "result": "Nomination Confirmed",
#                 "tie_breaker": "",
#                 "tie_breaker_vote": "",
#                 "document_number": "",
#                 "document_title": "",
#                 "democratic": {
#                     "yes": 28,
#                     "no": 18,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "Yes"
#                 },
#                 "republican": {
#                     "yes": 52,
#                     "no": 0,
#                     "present": 0,
#                     "not_voting": 0,
#                     "majority_position": "Yes"
#                 },
#                 "independent": {
#                     "yes": 1,
#                     "no": 1,
#                     "present": 0,
#                     "not_voting": 0
#                 },
#                 "total": {
#                     "yes": 81,
#                     "no": 19,
#                     "present": 0,
#                     "not_voting": 0
#                 }
#             }
#         ]
#     }
# }

# %% [markdown]
# # Fetching senate members (congress 80 to 115)

# %%
u = "https://api.propublica.org/congress/v1/{congress}/senate/members.json"

for i in range(80, 115 + 1):
    results = requests.get(url = u.format(congress=i), headers=HEADERS)
    df = pd.io.json.json_normalize(results.json()['results'][0]['members'])
    print(df.head(1))
    df.to_csv("data/senate_members/senate_members_{congress}.csv".format(congress=i))
# Out:
#                                              api_uri date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...    1892-08-20
#
#   fec_candidate_id first_name gender govtrack_id icpsr_id       id  in_office  \
# 0                      George      M      400722       52  A000062      False
#
#   last_name ... middle_name                            ocd_id party  \
# 0     Aiken ...       David  ocd-division/country:us/state:vt     R
#
#   senate_class seniority short_title state state_rank               title url
# 0            3         6        Sen.    VT             Senator, 3rd Class
#
# [1 rows x 22 columns]
#                                              api_uri date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...    1892-08-20
#
#   fec_candidate_id first_name gender govtrack_id icpsr_id       id  in_office  \
# 0                      George      M      400722       52  A000062      False
#
#   last_name ... middle_name                            ocd_id party  \
# 0     Aiken ...       David  ocd-division/country:us/state:vt     R
#
#   senate_class seniority short_title state state_rank               title url
# 0            3         9        Sen.    VT             Senator, 3rd Class
#
# [1 rows x 22 columns]
#                                              api_uri date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...    1892-08-20
#
#   fec_candidate_id first_name gender govtrack_id icpsr_id       id  in_office  \
# 0                      George      M      400722       52  A000062      False
#
#   last_name ... middle_name                            ocd_id party  \
# 0     Aiken ...       David  ocd-division/country:us/state:vt     R
#
#   senate_class seniority short_title state state_rank               title url
# 0            3        11        Sen.    VT             Senator, 3rd Class
#
# [1 rows x 22 columns]
#                                              api_uri date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...    1888-07-10
#
#   fec_candidate_id first_name gender govtrack_id icpsr_id       id  in_office  \
# 0                       Hazel      F      400673        9  A000010      False
#
#   last_name ... middle_name                            ocd_id party  \
# 0      Abel ...      Hempel  ocd-division/country:us/state:ne     R
#
#   senate_class seniority short_title state state_rank               title url
# 0            2         1        Sen.    NE             Senator, 2nd Class
#
# [1 rows x 22 columns]
#                                              api_uri date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...    1892-08-20
#
#   fec_candidate_id first_name gender govtrack_id icpsr_id       id  in_office  \
# 0                      George      M      400722       52  A000062      False
#
#   last_name ... middle_name                            ocd_id party  \
# 0     Aiken ...       David  ocd-division/country:us/state:vt     R
#
#   senate_class seniority short_title state state_rank               title url
# 0            3        15        Sen.    VT             Senator, 3rd Class
#
# [1 rows x 22 columns]
#                                              api_uri date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...    1892-08-20
#
#   fec_candidate_id first_name gender govtrack_id icpsr_id       id  in_office  \
# 0                      George      M      400722       52  A000062      False
#
#   last_name ... middle_name                            ocd_id party  \
# 0     Aiken ...       David  ocd-division/country:us/state:vt     R
#
#   senate_class seniority short_title state state_rank               title url
# 0            3        16        Sen.    VT             Senator, 3rd Class
#
# [1 rows x 22 columns]
#                                              api_uri date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...    1892-08-20
#
#   fec_candidate_id first_name gender google_entity_id govtrack_id icpsr_id  \
# 0                      George      M              NaN      400722       52
#
#         id  in_office ... middle_name                            ocd_id party  \
# 0  A000062      False ...       David  ocd-division/country:us/state:vt     R
#
#   senate_class seniority short_title state state_rank               title url
# 0            3        19        Sen.    VT             Senator, 3rd Class
#
# [1 rows x 23 columns]
#                                              api_uri date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...    1892-08-20
#
#   fec_candidate_id first_name gender google_entity_id govtrack_id icpsr_id  \
# 0                      George      M              NaN      400722       52
#
#         id  in_office ... middle_name                            ocd_id party  \
# 0  A000062      False ...       David  ocd-division/country:us/state:vt     R
#
#   senate_class seniority short_title state state_rank               title url
# 0            3        21        Sen.    VT             Senator, 3rd Class
#
# [1 rows x 23 columns]
#                                              api_uri cspan_id date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...      NaN    1892-08-20
#
#   fec_candidate_id first_name gender google_entity_id govtrack_id icpsr_id  \
# 0                      George      M              NaN      400722       52
#
#         id ...                            ocd_id party senate_class seniority  \
# 0  A000062 ...  ocd-division/country:us/state:vt     R            3        23
#
#   short_title state state_rank               title twitter_account url
# 0        Sen.    VT             Senator, 3rd Class             NaN
#
# [1 rows x 25 columns]
#                                              api_uri cspan_id date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...      NaN    1892-08-20
#
#   fec_candidate_id first_name gender google_entity_id govtrack_id icpsr_id  \
# 0                      George      M              NaN      400722       52
#
#         id ...                            ocd_id party senate_class seniority  \
# 0  A000062 ...  ocd-division/country:us/state:vt     R            3        25
#
#   short_title state state_rank               title twitter_account url
# 0        Sen.    VT             Senator, 3rd Class             NaN
#
# [1 rows x 25 columns]
#                                              api_uri cspan_id date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...      NaN    1892-08-20
#
#   fec_candidate_id first_name gender google_entity_id govtrack_id icpsr_id  \
# 0                      George      M              NaN      400722       52
#
#         id ...                            ocd_id party senate_class seniority  \
# 0  A000062 ...  ocd-division/country:us/state:vt     R            3        27
#
#   short_title state state_rank               title twitter_account url
# 0        Sen.    VT             Senator, 3rd Class             NaN
#
# [1 rows x 25 columns]
#                                              api_uri cspan_id date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...      NaN    1892-08-20
#
#   fec_candidate_id first_name gender google_entity_id govtrack_id icpsr_id  \
# 0                      George      M              NaN      400722       52
#
#         id ...  party senate_class seniority short_title state state_rank  \
# 0  A000062 ...      R            3        29        Sen.    VT
#
#   suffix               title twitter_account url
# 0    NaN  Senator, 3rd Class             NaN
#
# [1 rows x 26 columns]
#                                              api_uri cspan_id date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...      NaN    1892-08-20
#
#   fec_candidate_id first_name gender google_entity_id govtrack_id icpsr_id  \
# 0                      George      M              NaN      400722       52
#
#         id ...  party senate_class seniority short_title state state_rank  \
# 0  A000062 ...      R            3        31        Sen.    VT
#
#   suffix               title twitter_account url
# 0    NaN  Senator, 3rd Class             NaN
#
# [1 rows x 26 columns]
#                                              api_uri cspan_id date_of_birth  \
# 0  https://api.propublica.org/congress/v1/members...      NaN    1931-02-24
#
#   fec_candidate_id first_name gender google_entity_id govtrack_id icpsr_id  \
# 0                       James      M              NaN      400679    13000
#
#         id ...  party senate_class seniority short_title state state_rank  \
# 0  A000017 ...      D            2         1        Sen.    SD
#
#   suffix               title twitter_account url
# 0    NaN  Senator, 2nd Class             NaN
#
# [1 rows x 26 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1931-02-24              NaN                       James      M
#
#   google_entity_id govtrack_id       ...       seniority short_title  state  \
# 0              NaN      400679       ...               3        Sen.     SD
#
#   state_rank suffix               title twitter_account url votesmart_id  \
# 0               NaN  Senator, 2nd Class             NaN              NaN
#
#   youtube_account
# 0             NaN
#
# [1 rows x 30 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1931-02-24              NaN                       James      M
#
#   google_entity_id govtrack_id       ...       seniority short_title  state  \
# 0              NaN      400679       ...               5        Sen.     SD
#
#   state_rank suffix               title twitter_account url votesmart_id  \
# 0               NaN  Senator, 2nd Class             NaN              NaN
#
#   youtube_account
# 0             NaN
#
# [1 rows x 31 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1937-03-16              NaN                     William      M
#
#   google_entity_id govtrack_id       ...       seniority short_title  state  \
# 0              NaN      400927       ...               1        Sen.     CO
#
#   state_rank suffix               title twitter_account url votesmart_id  \
# 0               NaN  Senator, 2nd Class             NaN              NaN
#
#   youtube_account
# 0             NaN
#
# [1 rows x 31 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1923-02-13              NaN                       James      M
#
#   google_entity_id govtrack_id       ...       seniority short_title  state  \
# 0              NaN      400672       ...               1        Sen.     SD
#
#   state_rank suffix               title twitter_account url votesmart_id  \
# 0               NaN  Senator, 3rd Class             NaN              NaN
#
#   youtube_account
# 0             NaN
#
# [1 rows x 31 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1923-02-13              NaN                       James      M
#
#   google_entity_id govtrack_id       ...       seniority short_title  state  \
# 0              NaN      400672       ...               3        Sen.     SD
#
#   state_rank suffix               title twitter_account url votesmart_id  \
# 0               NaN  Senator, 3rd Class             NaN              NaN
#
#   youtube_account
# 0             NaN
#
# [1 rows x 31 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1923-02-13              NaN                       James      M
#
#   google_entity_id govtrack_id       ...       seniority short_title  state  \
# 0              NaN      400672       ...               5        Sen.     SD
#
#   state_rank suffix               title twitter_account url votesmart_id  \
# 0               NaN  Senator, 3rd Class             NaN              NaN
#
#   youtube_account
# 0             NaN
#
# [1 rows x 31 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1927-01-13              NaN                    Brockman    NaN
#
#   google_entity_id govtrack_id       ...       seniority short_title  state  \
# 0              NaN      400692       ...               1        Sen.     WA
#
#   state_rank suffix               title twitter_account url votesmart_id  \
# 0               NaN  Senator, 3rd Class             NaN              NaN
#
#   youtube_account
# 0             NaN
#
# [1 rows x 31 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1927-01-13              NaN                    Brockman    NaN
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0              NaN      400692       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 3rd Class             0         638             NaN
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 89.22           NaN             NaN
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1927-01-13              NaN                    Brockman    NaN
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0              NaN      400692       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 3rd Class             1         550             NaN
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 89.95           NaN             NaN
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN     8704
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1924-09-11              NaN                      Daniel      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0        /m/01rbrq      300001       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             0         726    SenatorAkaka
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                  92.7           NaN    senatorakaka
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1952-06-12              NaN                     Spencer      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0              NaN      400555       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             0         916             NaN
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 92.58           NaN             NaN
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1952-06-12              NaN                     Spencer      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0              NaN      400555       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             0         612             NaN
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 91.99           NaN             NaN
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN      NaN
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1952-06-12              NaN                     Spencer      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0              NaN      400555       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             0         672             NaN
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 89.88           NaN             NaN
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN     8704
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1924-09-11              NaN                      Daniel      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0        /m/01rbrq      300001       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             1         633    SenatorAkaka
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 93.92           NaN    senatorakaka
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN     8704
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1924-09-11              NaN                      Daniel      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0        /m/01rbrq      300001       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             0         675    SenatorAkaka
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 92.96           NaN    senatorakaka
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN     8704
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1924-09-11              NaN                      Daniel      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0        /m/01rbrq      300001       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             0         645    SenatorAkaka
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 93.32           NaN    senatorakaka
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN     8704
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1924-09-11              NaN                      Daniel      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0        /m/01rbrq      300001       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             0         657    SenatorAkaka
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 96.18           NaN    senatorakaka
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN     8704
#
#   date_of_birth facebook_account fec_candidate_id first_name gender  \
# 0    1924-09-11              NaN                      Daniel      M
#
#   google_entity_id govtrack_id       ...       state_rank suffix  \
# 0        /m/01rbrq      300001       ...                     NaN
#
#                 title total_present total_votes twitter_account url  \
# 0  Senator, 1st Class             0         677    SenatorAkaka
#
#    votes_with_party_pct  votesmart_id youtube_account
# 0                 96.45           NaN    senatorakaka
#
# [1 rows x 37 columns]
#                                              api_uri crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...    NaN     8704
#
#   date_of_birth  dw_nominate facebook_account fec_candidate_id first_name  \
# 0    1924-09-11       -0.419              NaN                      Daniel
#
#   gender google_entity_id       ...        state_rank suffix  \
# 0      M        /m/01rbrq       ...                      NaN
#
#                 title  total_present total_votes twitter_account url  \
# 0  Senator, 1st Class              0         487    SenatorAkaka
#
#   votes_with_party_pct  votesmart_id  youtube_account
# 0                95.17           NaN     senatorakaka
#
# [1 rows x 38 columns]
#                                              api_uri     crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...  N00009888        5
#
#   date_of_birth  dw_nominate       facebook_account fec_candidate_id  \
# 0    1940-07-03        0.323  senatorlamaralexander
#
#   first_name gender google_entity_id       ...        state_rank suffix  \
# 0      Lamar      M        /m/01rbs3       ...                      NaN
#
#                 title  total_present  total_votes twitter_account  \
# 0  Senator, 2nd Class              0          657    SenAlexander
#
#                                        url votes_with_party_pct votesmart_id  \
# 0  https://www.alexander.senate.gov/public                85.97        15691
#
#    youtube_account
# 0   lamaralexander
#
# [1 rows x 39 columns]
#                                              api_uri     crp_id cspan_id  \
# 0  https://api.propublica.org/congress/v1/members...  N00009888        5
#
#   date_of_birth  dw_nominate       facebook_account fec_candidate_id  \
# 0    1940-07-03        0.323  senatorlamaralexander        P60003225
#
#   first_name gender google_entity_id       ...        state_rank suffix  \
# 0      Lamar      M        /m/01rbs3       ...                      NaN
#
#                 title  total_present total_votes twitter_account  \
# 0  Senator, 2nd Class              0         502    SenAlexander
#
#                                        url votes_with_party_pct  votesmart_id  \
# 0  https://www.alexander.senate.gov/public                85.45         15691
#
#    youtube_account
# 0   lamaralexander
#
# [1 rows x 38 columns]
#                                              api_uri  \
# 0  https://api.propublica.org/congress/v1/members...
#
#                                         contact_form     crp_id cspan_id  \
# 0  http://www.alexander.senate.gov/public/index.c...  N00009888        5
#
#   date_of_birth  dw_nominate       facebook_account           fax  \
# 0    1940-07-03        0.323  senatorlamaralexander  202-228-3398
#
#   fec_candidate_id first_name       ...       state_rank suffix  \
# 0        S2TN00058      Lamar       ...           senior    NaN
#
#                 title total_present total_votes  twitter_account  \
# 0  Senator, 2nd Class             0         544     SenAlexander
#
#                                        url votes_with_party_pct votesmart_id  \
# 0  https://www.alexander.senate.gov/public                96.91        15691
#
#   youtube_account
# 0  lamaralexander
#
# [1 rows x 43 columns]

# %% [markdown]
# # Fetching vote data from senate

# %%
# Request config
u = "https://api.propublica.org/congress/v1/senate/votes/recent.json?offset={offset}"


votes_list = []
data_available = True
request_offset = 6000

while data_available :
    res = requests.get(url = u.format(offset = request_offset), headers = HEADERS)
    data_available = int(res.json()['results']['num_results']) > 0
    
    if data_available:
        votes = res.json()['results']['votes']
        print(request_offset)
        print(json.dumps(votes, indent=4))
        pd.io.json.json_normalize(votes, record_prefix=True)

df = pd.concat(votes_list)

print(df.head(10))
df.to_csv("data/votes/votes.csv".format(congress=i))
# Out:
# 6000
# [
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 167,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00167.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00167",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/167.json",
#         "bill": {
#             "bill_id": "h.r.1664-106",
#             "number": "H.R..1664",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Cloture Motion",
#         "description": "Motion to Invoke Cloture on Motion to Proceed to H.R.1664; Kosovo and Southwest Asia Emergency Supplemental Appropriations Act, 1999",
#         "vote_type": "3/5",
#         "date": "1999-06-15",
#         "time": "17:16:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 45,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 26,
#             "no": 28,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "No"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 71,
#             "no": 28,
#             "present": 0,
#             "not_voting": 1
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 166,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00166.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00166",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/166.json",
#         "bill": {
#             "bill_id": "s.557-106",
#             "number": "S..557",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Cloture Motion ",
#         "description": "Motion to Invoke Cloture on Amdt. No 297 to S.557; In the nature of a substitute.",
#         "vote_type": "3/5",
#         "date": "1999-06-15",
#         "time": "16:22:00",
#         "result": "Rejected",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 0,
#             "no": 45,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 53,
#             "no": 1,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 53,
#             "no": 46,
#             "present": 0,
#             "not_voting": 1
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 165,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00165.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00165",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/165.json",
#         "bill": {
#             "bill_id": "h.r.775-106",
#             "number": "H.R..775",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On Passage of the Bill",
#         "description": "H.R.775 as Amended; Year 2000 Readiness and Responsibility Act",
#         "vote_type": "1/2",
#         "date": "1999-06-15",
#         "time": "14:55:00",
#         "result": "Passed",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 12,
#             "no": 33,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 50,
#             "no": 4,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 62,
#             "no": 37,
#             "present": 0,
#             "not_voting": 1
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 164,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00164.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00164",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/164.json",
#         "bill": {
#             "bill_id": "s.96-106",
#             "number": "S..96",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Amendment ",
#         "description": "Gregg Amendment No. 624 as Modified; To provide for the suspension of penalties for certain year 2000 failures by small business concerns.",
#         "vote_type": "1/2",
#         "date": "1999-06-15",
#         "time": "14:18:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 17,
#             "no": 28,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 54,
#             "no": 0,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 71,
#             "no": 28,
#             "present": 0,
#             "not_voting": 1
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 163,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00163.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00163",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/163.json",
#         "bill": {
#             "bill_id": "s.96-106",
#             "number": "S..96",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Motion to Table ",
#         "description": "Motion to Table Boxer Amdt. No.621, as Modified; To ensure that manufacturers provide Y2K fixes if available.",
#         "vote_type": "1/2",
#         "date": "1999-06-10",
#         "time": "16:14:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 14,
#             "no": 31,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 52,
#             "no": 1,
#             "present": 0,
#             "not_voting": 2,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 66,
#             "no": 32,
#             "present": 0,
#             "not_voting": 2
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 162,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00162.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00162",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/162.json",
#         "bill": {
#             "bill_id": "s.96-106",
#             "number": "S..96",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Amendment ",
#         "description": "Edwards Amendment No. 620; To provide that certain companies, selling non-Y2K-compliant products beginning in 1999, not be included under the protections as outlined in the substitute amendment.",
#         "vote_type": "1/2",
#         "date": "1999-06-10",
#         "time": "12:10:00",
#         "result": "Rejected",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 34,
#             "no": 10,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 2,
#             "no": 52,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "No"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 36,
#             "no": 62,
#             "present": 0,
#             "not_voting": 2
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 161,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00161.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00161",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/161.json",
#         "bill": {
#             "bill_id": "s.96-106",
#             "number": "S..96",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Amendment ",
#         "description": "Edwards Amendment No. 619; To provide that a party to a Y2K action making a tort claim may only recover for economic losses to the extent allowed under applicable state or federal law in effect on January 1, 1999.",
#         "vote_type": "1/2",
#         "date": "1999-06-10",
#         "time": "11:43:00",
#         "result": "Rejected",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 38,
#             "no": 6,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 3,
#             "no": 51,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "No"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 41,
#             "no": 57,
#             "present": 0,
#             "not_voting": 2
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 160,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00160.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00160",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/160.json",
#         "bill": {
#             "bill_id": "s.96-106",
#             "number": "S..96",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Amendment ",
#         "description": "Leahy Amdt. No. 6111; To exclude consumers from the Act's restrictions on seeking redress for the harm caused by Y2K computer failures.",
#         "vote_type": "1/2",
#         "date": "1999-06-09",
#         "time": "18:54:00",
#         "result": "Rejected",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 32,
#             "no": 12,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 0,
#             "no": 53,
#             "present": 0,
#             "not_voting": 2,
#             "majority_position": "No"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 32,
#             "no": 65,
#             "present": 0,
#             "not_voting": 3
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 159,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00159.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00159",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/159.json",
#         "bill": {
#             "bill_id": "s.96-106",
#             "number": "S..96",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Motion to Table ",
#         "description": "Motion to Table Kerry Amdt. No. 610; To regulate interstate commerce by making provision for dealing with losses arising from Year 2000 Problem-related failures that may disrupt communications, intermodal transportation, and other matters affecting inters",
#         "vote_type": "1/2",
#         "date": "1999-06-09",
#         "time": "18:03:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 7,
#             "no": 38,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 50,
#             "no": 3,
#             "present": 0,
#             "not_voting": 2,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 57,
#             "no": 41,
#             "present": 0,
#             "not_voting": 2
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 158,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00158.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00158",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/158.json",
#         "bill": {
#             "bill_id": "s.1122-106",
#             "number": "S..1122",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On Passage of the Bill",
#         "description": "S.1122, as amended; Department of Defense Appropriations Act, 2000",
#         "vote_type": "1/2",
#         "date": "1999-06-08",
#         "time": "18:17:00",
#         "result": "Passed",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 40,
#             "no": 4,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 53,
#             "no": 0,
#             "present": 0,
#             "not_voting": 2,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 93,
#             "no": 4,
#             "present": 0,
#             "not_voting": 3
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 157,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00157.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00157",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/157.json",
#         "bill": {
#             "bill_id": "s.1122-106",
#             "number": "S..1122",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Motion to Table ",
#         "description": "Motion to table Boxer Amdt. No. 541; To substitute for section 8106 (relating to operational support aircraft) a requirement for a report.",
#         "vote_type": "1/2",
#         "date": "1999-06-08",
#         "time": "17:39:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 18,
#             "no": 26,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 48,
#             "no": 5,
#             "present": 0,
#             "not_voting": 2,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 66,
#             "no": 31,
#             "present": 0,
#             "not_voting": 3
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 156,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00156.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00156",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/156.json",
#         "bill": {
#             "bill_id": "s.1122-106",
#             "number": "S..1122",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Amendment ",
#         "description": "McCain Amendment No. 584; To reduce amounts appropriated for unrequested, low-priority, unnecessary, and wasteful spending.",
#         "vote_type": "1/2",
#         "date": "1999-06-08",
#         "time": "15:46:00",
#         "result": "Rejected",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 8,
#             "no": 36,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 8,
#             "no": 45,
#             "present": 0,
#             "not_voting": 2,
#             "majority_position": "No"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 16,
#             "no": 81,
#             "present": 0,
#             "not_voting": 3
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 155,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00155.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00155",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/155.json",
#         "bill": {
#             "bill_id": "s.1122-106",
#             "number": "S..1122",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Amendment ",
#         "description": "Grassley Amendment No. 540; To reduce to $500,000 the threshold amount for the applicability of the requirement for advanced matching of Department of Defense disbursements to particular obligations.",
#         "vote_type": "1/2",
#         "date": "1999-06-08",
#         "time": "09:45:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 41,
#             "no": 0,
#             "present": 0,
#             "not_voting": 4,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 52,
#             "no": 0,
#             "present": 0,
#             "not_voting": 3,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 93,
#             "no": 0,
#             "present": 0,
#             "not_voting": 7
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 154,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00154.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00154",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/154.json",
#         "bill": {
#             "bill_id": "s.1059-106",
#             "number": "S..1059",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On Passage of the Bill",
#         "description": "S.1059 As Amended; National Defense Authorization Act for Fiscal Year 2000",
#         "vote_type": "1/2",
#         "date": "1999-05-27",
#         "time": "19:46:00",
#         "result": "Passed",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 39,
#             "no": 3,
#             "present": 0,
#             "not_voting": 3,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 53,
#             "no": 0,
#             "present": 0,
#             "not_voting": 2,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 92,
#             "no": 3,
#             "present": 0,
#             "not_voting": 5
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 153,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00153.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00153",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/153.json",
#         "bill": {
#             "bill_id": "s.1059-106",
#             "number": "S..1059",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Motion to Table ",
#         "description": "Motion to Table Feingold Amdt. No. 443; To limit the total cost of the F/A-18E/F aircraft program.",
#         "vote_type": "1/2",
#         "date": "1999-05-27",
#         "time": "12:21:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 34,
#             "no": 10,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 53,
#             "no": 1,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 87,
#             "no": 11,
#             "present": 0,
#             "not_voting": 2
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 152,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00152.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00152",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/152.json",
#         "bill": {
#             "bill_id": "s.1059-106",
#             "number": "S..1059",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Amendment ",
#         "description": "Kennedy Amdt. No. 442; To express the sense of Congress regarding the continuation of sanctions against Libya.",
#         "vote_type": "1/2",
#         "date": "1999-05-27",
#         "time": "11:50:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 45,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 53,
#             "no": 0,
#             "present": 0,
#             "not_voting": 2,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 98,
#             "no": 0,
#             "present": 0,
#             "not_voting": 2
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 151,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00151.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00151",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/151.json",
#         "bill": {
#             "bill_id": "s.1059-106",
#             "number": "S..1059",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Motion to Table ",
#         "description": "Motion to Table Smith Amdt. No. 406; To prohibit, effective October 1, 1999, the use of funds for military operations in the Federal Republic of Yugoslavia (Serbia and Montenegro) unless Congress enacts speific authorization in law for the conduct of thos",
#         "vote_type": "1/2",
#         "date": "1999-05-26",
#         "time": "20:03:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 42,
#             "no": 2,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "republican": {
#             "yes": 35,
#             "no": 19,
#             "present": 0,
#             "not_voting": 1,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 77,
#             "no": 21,
#             "present": 0,
#             "not_voting": 2
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 150,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00150.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00150",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/150.json",
#         "bill": {
#             "bill_id": "s.1059-106",
#             "number": "S..1059",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Motion to Reconsider ",
#         "description": "Motion to Reconsider the vote Re: Amdt. No. 392 was not agreed to.; To delete language which the Department of Justice has stated would '...seriously undermine the safety and security of America's federal prisons.'",
#         "vote_type": "1/2",
#         "date": "1999-05-26",
#         "time": "17:07:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 11,
#             "no": 34,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 40,
#             "no": 15,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 51,
#             "no": 49,
#             "present": 0,
#             "not_voting": 0
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 149,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00149.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00149",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/149.json",
#         "bill": {
#             "bill_id": "s.1059-106",
#             "number": "S..1059",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Motion to Table ",
#         "description": "Motion to Table Kerrey Amdt. No. 395; To strike section 1041, relating to a limitation on retirement or dismantlement of strategic nuclear delivery systems.",
#         "vote_type": "1/2",
#         "date": "1999-05-26",
#         "time": "16:40:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 4,
#             "no": 41,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 52,
#             "no": 3,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 56,
#             "no": 44,
#             "present": 0,
#             "not_voting": 0
#         }
#     },
#     {
#         "congress": 106,
#         "chamber": "Senate",
#         "session": 1,
#         "roll_call": 148,
#         "source": "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1061/vote_106_1_00148.xml",
#         "url": "https://www.senate.gov/legislative/LIS/roll_call_lists/roll_call_vote_cfm.cfm?congress=106&session=1&vote=00148",
#         "vote_uri": "https://api.propublica.org/congress/v1/106/senate/sessions/1/votes/148.json",
#         "bill": {
#             "bill_id": "s.1059-106",
#             "number": "S..1059",
#             "sponsor_id": null,
#             "api_uri": null,
#             "title": null,
#             "latest_action": null
#         },
#         "amendment": {},
#         "question": "On the Motion to Table ",
#         "description": "Motion to Table Murray Amdt. No. 397; To repeal the restriction on use of the Department of Defense facilities for privately funded abortions.",
#         "vote_type": "1/2",
#         "date": "1999-05-26",
#         "time": "15:24:00",
#         "result": "Agreed to",
#         "tie_breaker": "",
#         "tie_breaker_vote": "",
#         "document_number": "",
#         "document_title": "",
#         "democratic": {
#             "yes": 2,
#             "no": 43,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "No"
#         },
#         "republican": {
#             "yes": 49,
#             "no": 6,
#             "present": 0,
#             "not_voting": 0,
#             "majority_position": "Yes"
#         },
#         "independent": {
#             "yes": 0,
#             "no": 0,
#             "present": 0,
#             "not_voting": 0
#         },
#         "total": {
#             "yes": 51,
#             "no": 49,
#             "present": 0,
#             "not_voting": 0
#         }
#     }
# ]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-86d2a71412b5> in <module>()
#      15         print(request_offset)
#      16         print(json.dumps(votes, indent=4))
# ---> 17         pd.io.json.json_normalize(votes, record_prefix=True)
#      18
#      19 df = pd.concat(votes_list)
#
# D:\Programs\Anaconda\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     201             # TODO: handle record value which are lists, at least error
#     202             #       reasonably
# --> 203             data = nested_to_record(data, sep=sep)
#     204         return DataFrame(data)
#     205     elif not isinstance(record_path, list):
#
# D:\Programs\Anaconda\lib\site-packages\pandas\io\json\normalize.py in nested_to_record(ds, prefix, sep, level)
#      86             else:
#      87                 v = new_d.pop(k)
# ---> 88                 new_d.update(nested_to_record(v, newkey, sep, level + 1))
#      89         new_ds.append(new_d)
#      90
#
# D:\Programs\Anaconda\lib\site-packages\pandas\io\json\normalize.py in nested_to_record(ds, prefix, sep, level)
#      82                     new_d[newkey] = v
#      83                 if v is None:  # pop the key if the value is None
# ---> 84                     new_d.pop(k)
#      85                 continue
#      86             else:
#
# KeyError: 'sponsor_id'

# %%
pd.__version__
# Out:
# '0.23.0'
